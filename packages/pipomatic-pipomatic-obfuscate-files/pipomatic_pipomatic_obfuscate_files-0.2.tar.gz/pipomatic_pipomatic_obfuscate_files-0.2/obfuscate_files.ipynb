# %% [markdown]
# To do:
#
# Replace each unique value with the same random text

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from pandas.api.types import is_datetime64_any_dtype, is_numeric_dtype, is_integer_dtype, is_object_dtype, is_string_dtype

# %%
def delete_files(folder):
    file_generator = folder.glob('**/*')
    file_list = list(file_generator)
    for file in file_list:
        file.unlink()
    return list(file_list)


def move_files(samples_folder, file_to_copy, destination_folder):
    (destination_folder / file_to_copy).write_bytes((samples_folder / file_to_copy).read_bytes())
    return file_to_copy


def convert_to_numeric_and_date(df, dayfirst=True):
    for column in df.columns:
        if is_object_dtype(df[column]) or is_string_dtype(df[column]):
            try:
                df[column] = pd.to_numeric(df[column], downcast='integer')
            except:
                try:
                    df[column] = df[column].str.replace('$', '')
                    df[column] = df[column].str.replace(',', '')
                    df[column] = pd.to_numeric(df[column])
                except:
                    try:
                        df[column] = pd.to_datetime(df[column], dayfirst=dayfirst)
                    except:
                        pass
    return df


def random_dates(start, end, seed=1, replace=True, number_of_rows=100):
    dates = pd.date_range(start, end).to_series()
    return dates.sample(number_of_rows, replace=replace, random_state=seed).index
    
    
def dataframe_obfuscator(df, number_of_rows=100):
    for column in df.columns:
        if is_datetime64_any_dtype(df[column]):
            df[column] = random_dates(min(df[column]),max(df[column]), seed=1)
        elif is_integer_dtype(df[column]):
            df[column] = df[column].fillna(0)
            if min(df[column]) < max(df[column]):
                df[column] = np.random.randint(min(df[column]),max(df[column]),size=(number_of_rows))
            else:
                df[column] = min(df[column])
        elif is_numeric_dtype(df[column]):
            df[column] = df[column].fillna(0)
            df[column] = np.random.uniform(min(df[column]),max(df[column]),size=(number_of_rows))
        else:
            df[column] = 'random text'
    return df


def obfuscate_csv(data_file, dayfirst=True, number_of_rows=100):
    df = pd.read_csv(data_file, nrows=number_of_rows)
    df = convert_to_numeric_and_date(df)
    df = dataframe_obfuscator(df)
    df.to_csv(data_file, header=True, index=False)
    return df


def obfuscate_excel(data_file, dayfirst=True, number_of_rows=100):
    df = pd.read_excel(data_file, nrows=number_of_rows)
    display(df.head())
    df = convert_to_numeric_and_date(df)
    df = dataframe_obfuscator(df)
    df.to_excel(data_file, header=True, index=False)
    return df

# %%
p = Path.cwd()
obfuscate_csv(p / 'data' / 'data.csv', dayfirst=True, number_of_rows=100)
# Out:
#    Purchase_Order_Number_Combined District_Code Warehouse_Identification  \
# 0                     random text   random text              random text
# 1                     random text   random text              random text
# 2                     random text   random text              random text
# 3                     random text   random text              random text
# 4                     random text   random text              random text
# 5                     random text   random text              random text
# 6                     random text   random text              random text
# 7                     random text   random text              random text
# 8                     random text   random text              random text
# 9                     random text   random text              random text
# 10                    random text   random text              random text
# 11                    random text   random text              random text
# 12                    random text   random text              random text
# 13                    random text   random text              random text
# 14                    random text   random text              random text
# 15                    random text   random text              random text
# 16                    random text   random text              random text
# 17                    random text   random text              random text
# 18                    random text   random text              random text
# 19                    random text   random text              random text
# 20                    random text   random text              random text
# 21                    random text   random text              random text
# 22                    random text   random text              random text
# 23                    random text   random text              random text
# 24                    random text   random text              random text
# 25                    random text   random text              random text
# 26                    random text   random text              random text
# 27                    random text   random text              random text
# 28                    random text   random text              random text
# 29                    random text   random text              random text
# ..                            ...           ...                      ...
# 70                    random text   random text              random text
# 71                    random text   random text              random text
# 72                    random text   random text              random text
# 73                    random text   random text              random text
# 74                    random text   random text              random text
# 75                    random text   random text              random text
# 76                    random text   random text              random text
# 77                    random text   random text              random text
# 78                    random text   random text              random text
# 79                    random text   random text              random text
# 80                    random text   random text              random text
# 81                    random text   random text              random text
# 82                    random text   random text              random text
# 83                    random text   random text              random text
# 84                    random text   random text              random text
# 85                    random text   random text              random text
# 86                    random text   random text              random text
# 87                    random text   random text              random text
# 88                    random text   random text              random text
# 89                    random text   random text              random text
# 90                    random text   random text              random text
# 91                    random text   random text              random text
# 92                    random text   random text              random text
# 93                    random text   random text              random text
# 94                    random text   random text              random text
# 95                    random text   random text              random text
# 96                    random text   random text              random text
# 97                    random text   random text              random text
# 98                    random text   random text              random text
# 99                    random text   random text              random text
#
#       FPA_Group  FPA_Agreement_Number  FPA_Item_Number Supplier_Price_Code1  \
# 0   random text              0.483422              240          random text
# 1   random text              0.155925              113          random text
# 2   random text              0.466748               65          random text
# 3   random text              0.611747               55          random text
# 4   random text              0.645384              239          random text
# 5   random text              0.284937              198          random text
# 6   random text              0.314530              212          random text
# 7   random text              0.810187              129          random text
# 8   random text              0.744603              119          random text
# 9   random text              0.545736               55          random text
# 10  random text              0.220191              190          random text
# 11  random text              0.283832              170          random text
# 12  random text              0.429247              139          random text
# 13  random text              0.158485              149          random text
# 14  random text              0.659177               91          random text
# 15  random text              0.483443              239          random text
# 16  random text              0.461245              205          random text
# 17  random text              0.733459              152          random text
# 18  random text              0.834741              162          random text
# 19  random text              0.244764               56          random text
# 20  random text              0.771099               79          random text
# 21  random text              0.202453              195          random text
# 22  random text              0.597199              207          random text
# 23  random text              0.826249              270          random text
# 24  random text              0.652245              129          random text
# 25  random text              0.479385              104          random text
# 26  random text              0.662852              126          random text
# 27  random text              0.480216               72          random text
# 28  random text              0.214792              248          random text
# 29  random text              0.308361              193          random text
# ..          ...                   ...              ...                  ...
# 70  random text              0.460007               57          random text
# 71  random text              0.168797              125          random text
# 72  random text              0.833247              252          random text
# 73  random text              0.478694               59          random text
# 74  random text              0.526127              216          random text
# 75  random text              0.279632               66          random text
# 76  random text              0.229279               89          random text
# 77  random text              0.447905              123          random text
# 78  random text              0.676692               59          random text
# 79  random text              0.255324               87          random text
# 80  random text              0.330283              128          random text
# 81  random text              0.173411              259          random text
# 82  random text              0.165542               60          random text
# 83  random text              0.465735              179          random text
# 84  random text              0.372555               58          random text
# 85  random text              0.413286              125          random text
# 86  random text              0.376271              239          random text
# 87  random text              0.734594              112          random text
# 88  random text              0.426599               89          random text
# 89  random text              0.434498              259          random text
# 90  random text              0.400362              200          random text
# 91  random text              0.191739              188          random text
# 92  random text              0.652123              111          random text
# 93  random text              0.216602              173          random text
# 94  random text              0.807172              195          random text
# 95  random text              0.759243              221          random text
# 96  random text              0.694579              177          random text
# 97  random text              0.481532              144          random text
# 98  random text              0.444337              122          random text
# 99  random text              0.205074              158          random text
#
#     UOI_Original_Quantity  UOI_Original_Net_Price1  UOI_Current_Quantity1  \
# 0              380.970106             7.496110e+06             106.306680
# 1              116.935619             4.521492e+06             397.081647
# 2              289.874272             4.182336e+06             267.065450
# 3              346.196715             1.583266e+06             539.049892
# 4              109.679231             1.794464e+06             469.582918
# 5              325.705708             2.811943e+06             429.134712
# 6              273.061480             4.092520e+06             223.654725
# 7              354.900024             6.833454e+06             333.373007
# 8              340.505519             6.547960e+06             215.277093
# 9              393.981229             6.697708e+06             126.103861
# 10             235.122400             6.948907e+06             368.762490
# 11             404.645611             2.320505e+06              99.965558
# 12             399.835230             8.102506e+06             333.963879
# 13             349.688632             1.820683e+06             141.216103
# 14             369.982720             6.605912e+06             230.974121
# 15              88.542961             4.665714e+06             398.883051
# 16             147.892691             6.092718e+06             447.054049
# 17             109.988197             4.472054e+06             569.638138
# 18             274.446920             6.359896e+06             397.354396
# 19             262.077760             5.556302e+06             519.110619
# 20             241.640315             2.791124e+06             231.892007
# 21             405.605230             6.389013e+06             464.750843
# 22             427.977687             1.966685e+06             389.322182
# 23             114.830708             7.256253e+06             194.302658
# 24             267.517186             1.457173e+06             312.741601
# 25             418.536732             1.387656e+06             409.227622
# 26             371.623466             4.186202e+06             279.665917
# 27             219.705320             6.194354e+06             295.588132
# 28             189.791919             1.758425e+06              92.329459
# 29             204.790051             5.033814e+06             250.659085
# ..                    ...                      ...                    ...
# 70             133.441478             2.178686e+06             326.899103
# 71             256.158460             7.669390e+06             177.148262
# 72             404.951710             3.321063e+06             412.189398
# 73             148.816996             6.254724e+06             304.925353
# 74             222.035873             7.097194e+06             470.291144
# 75             264.587035             5.654521e+06             441.225451
# 76             298.258872             3.079348e+06             184.512944
# 77             395.412629             5.310127e+06             268.750389
# 78             253.763288             3.922998e+06             210.774137
# 79             277.436217             2.846884e+06             314.540127
# 80             423.508688             5.629611e+06             170.461442
# 81              78.901050             3.679972e+06              95.554426
# 82              67.889757             1.646591e+06              90.728024
# 83              77.106085             6.977761e+06             444.851606
# 84             354.665628             1.575931e+06             184.631911
# 85             388.430023             5.464417e+06             519.009128
# 86             391.821776             6.881550e+06             226.814720
# 87             384.510505             5.459420e+06             232.379350
# 88              66.882961             2.793402e+06             142.299359
# 89             106.504698             6.604188e+06             568.402646
# 90             308.180613             1.875173e+06             289.738108
# 91             163.296595             5.541197e+06             131.890882
# 92             264.562374             3.406515e+06             170.140883
# 93             328.700648             7.832970e+06             415.585634
# 94             125.050081             5.753889e+06             428.207598
# 95             425.524780             2.420213e+06             460.978365
# 96              98.365880             5.677025e+06             305.408316
# 97             265.408305             6.916971e+06             461.420583
# 98             120.292008             2.357218e+06              97.370358
# 99             308.333002             2.000202e+06             467.296337
#
#          ...               Total    Stock_Code  Item_Name_line  \
# 0        ...         5409.274158  2.286721e+06     random text
# 1        ...         5051.924875  2.605108e+06     random text
# 2        ...         1036.484607  2.972920e+06     random text
# 3        ...         2999.118287  7.546787e+05     random text
# 4        ...          987.317227  1.661393e+06     random text
# 5        ...         3668.747308  7.514910e+05     random text
# 6        ...         3611.732790  1.957084e+06     random text
# 7        ...         4929.285644  2.649106e+06     random text
# 8        ...         4866.241007  5.511359e+05     random text
# 9        ...         3981.694781  1.331871e+06     random text
# 10       ...         5367.282692  1.986248e+06     random text
# 11       ...         1977.598877  2.186869e+06     random text
# 12       ...         1869.968199  1.888582e+06     random text
# 13       ...         5493.633364  1.628211e+06     random text
# 14       ...         2952.322929  1.005786e+06     random text
# 15       ...         4773.946785  2.048104e+06     random text
# 16       ...         3380.420054  1.000430e+06     random text
# 17       ...         3900.387986  2.828245e+06     random text
# 18       ...         1401.974070  9.553179e+05     random text
# 19       ...         4505.244259  2.387004e+06     random text
# 20       ...         2932.254808  1.100147e+06     random text
# 21       ...         5081.000571  1.237507e+06     random text
# 22       ...         1030.317083  1.539409e+06     random text
# 23       ...         3801.448041  1.686966e+06     random text
# 24       ...         2690.795680  1.330099e+06     random text
# 25       ...          993.515883  1.082564e+06     random text
# 26       ...         1808.049532  1.813251e+06     random text
# 27       ...         2823.507087  2.348183e+06     random text
# 28       ...         4554.398787  2.778335e+06     random text
# 29       ...         3043.305280  5.590414e+05     random text
# ..       ...                 ...           ...             ...
# 70       ...         3000.878066  7.490206e+05     random text
# 71       ...         4593.219029  1.015127e+06     random text
# 72       ...         5442.224324  2.931026e+06     random text
# 73       ...         3430.931124  1.136442e+06     random text
# 74       ...         5295.798604  9.954663e+05     random text
# 75       ...         1321.091823  2.199016e+06     random text
# 76       ...         5164.820569  1.844506e+06     random text
# 77       ...         2950.723773  2.212449e+06     random text
# 78       ...         4292.593629  6.573836e+05     random text
# 79       ...         4718.552875  1.403618e+06     random text
# 80       ...         2591.447512  1.050857e+06     random text
# 81       ...         2242.478080  7.376740e+05     random text
# 82       ...         5236.881489  2.358223e+06     random text
# 83       ...         4468.612388  2.348681e+06     random text
# 84       ...         5071.789684  1.408650e+06     random text
# 85       ...         5159.590666  2.454215e+06     random text
# 86       ...         3418.214194  1.536152e+06     random text
# 87       ...         2940.027399  7.761492e+05     random text
# 88       ...         1102.260722  8.867158e+05     random text
# 89       ...         3290.138808  2.397981e+06     random text
# 90       ...         4120.443505  1.641759e+06     random text
# 91       ...         4455.878895  3.047791e+06     random text
# 92       ...         4754.254089  1.165002e+06     random text
# 93       ...         4389.198881  1.401394e+06     random text
# 94       ...         5482.301097  3.047986e+06     random text
# 95       ...         1872.152041  6.408942e+05     random text
# 96       ...         4343.138962  2.408516e+06     random text
# 97       ...         1586.679971  5.396143e+05     random text
# 98       ...         2338.691223  2.390058e+06     random text
# 99       ...         1449.280732  1.413183e+06     random text
#
#    Stock_Description Employee_Identification     FullName Purchase_Order_Date  \
# 0        random text             random text  random text          2001-07-19
# 1        random text             random text  random text          2011-10-20
# 2        random text             random text  random text          2003-05-20
# 3        random text             random text  random text          2008-06-20
# 4        random text             random text  random text          2008-10-30
# 5        random text             random text  random text          2001-04-19
# 6        random text             random text  random text          2012-06-21
# 7        random text             random text  random text          2008-07-24
# 8        random text             random text  random text          2010-05-20
# 9        random text             random text  random text          2004-03-12
# 10       random text             random text  random text          2013-02-04
# 11       random text             random text  random text          2009-01-05
# 12       random text             random text  random text          2007-10-17
# 13       random text             random text  random text          2001-08-05
# 14       random text             random text  random text          2010-08-28
# 15       random text             random text  random text          2013-12-12
# 16       random text             random text  random text          2002-06-11
# 17       random text             random text  random text          2008-02-06
# 18       random text             random text  random text          2009-04-02
# 19       random text             random text  random text          2002-12-19
# 20       random text             random text  random text          2005-01-31
# 21       random text             random text  random text          2010-08-16
# 22       random text             random text  random text          2006-01-27
# 23       random text             random text  random text          2003-12-11
# 24       random text             random text  random text          2003-09-23
# 25       random text             random text  random text          2012-12-28
# 26       random text             random text  random text          2008-10-12
# 27       random text             random text  random text          2010-10-11
# 28       random text             random text  random text          2004-07-25
# 29       random text             random text  random text          2007-12-01
# ..               ...                     ...          ...                 ...
# 70       random text             random text  random text          2005-07-02
# 71       random text             random text  random text          2008-07-26
# 72       random text             random text  random text          2011-12-18
# 73       random text             random text  random text          2001-07-27
# 74       random text             random text  random text          2004-08-29
# 75       random text             random text  random text          2004-03-24
# 76       random text             random text  random text          2004-08-02
# 77       random text             random text  random text          2006-01-08
# 78       random text             random text  random text          2005-10-26
# 79       random text             random text  random text          2008-12-18
# 80       random text             random text  random text          2002-03-02
# 81       random text             random text  random text          2005-10-29
# 82       random text             random text  random text          2013-08-30
# 83       random text             random text  random text          2013-05-27
# 84       random text             random text  random text          2004-12-13
# 85       random text             random text  random text          2012-01-07
# 86       random text             random text  random text          2002-11-11
# 87       random text             random text  random text          2008-06-17
# 88       random text             random text  random text          2003-10-29
# 89       random text             random text  random text          2013-07-29
# 90       random text             random text  random text          2005-03-17
# 91       random text             random text  random text          2005-10-30
# 92       random text             random text  random text          2011-07-17
# 93       random text             random text  random text          2011-05-17
# 94       random text             random text  random text          2001-03-02
# 95       random text             random text  random text          2001-08-22
# 96       random text             random text  random text          2009-05-05
# 97       random text             random text  random text          2006-03-07
# 98       random text             random text  random text          2003-05-04
# 99       random text             random text  random text          2001-04-27
#
#    Supplier_Number Supplier_Name Item_Status_Code
# 0      random text   random text                1
# 1      random text   random text                1
# 2      random text   random text                1
# 3      random text   random text                1
# 4      random text   random text                1
# 5      random text   random text                1
# 6      random text   random text                1
# 7      random text   random text                1
# 8      random text   random text                1
# 9      random text   random text                1
# 10     random text   random text                1
# 11     random text   random text                1
# 12     random text   random text                1
# 13     random text   random text                1
# 14     random text   random text                1
# 15     random text   random text                1
# 16     random text   random text                1
# 17     random text   random text                1
# 18     random text   random text                1
# 19     random text   random text                1
# 20     random text   random text                1
# 21     random text   random text                1
# 22     random text   random text                1
# 23     random text   random text                1
# 24     random text   random text                1
# 25     random text   random text                1
# 26     random text   random text                1
# 27     random text   random text                1
# 28     random text   random text                1
# 29     random text   random text                1
# ..             ...           ...              ...
# 70     random text   random text                1
# 71     random text   random text                1
# 72     random text   random text                1
# 73     random text   random text                1
# 74     random text   random text                1
# 75     random text   random text                1
# 76     random text   random text                1
# 77     random text   random text                1
# 78     random text   random text                1
# 79     random text   random text                1
# 80     random text   random text                1
# 81     random text   random text                1
# 82     random text   random text                1
# 83     random text   random text                1
# 84     random text   random text                1
# 85     random text   random text                1
# 86     random text   random text                1
# 87     random text   random text                1
# 88     random text   random text                1
# 89     random text   random text                1
# 90     random text   random text                1
# 91     random text   random text                1
# 92     random text   random text                1
# 93     random text   random text                1
# 94     random text   random text                1
# 95     random text   random text                1
# 96     random text   random text                1
# 97     random text   random text                1
# 98     random text   random text                1
# 99     random text   random text                1
#
# [100 rows x 21 columns]

# %%
p = Path.cwd()
obfuscate_excel(p / 'data' / 'data.xls', dayfirst=True, number_of_rows=100)
# Out:
#   District Code Purchase Order Number  Purchase Order Item Number  \
# 0   random text           random text                           1
# 1   random text           random text                           1
# 2   random text           random text                           1
# 3   random text           random text                           1
# 4   random text           random text                           1
#
#   Warehouse ID Item Description Detail Date of Purchase Order  \
# 0  random text             random text             2004-05-24
# 1  random text             random text             2014-08-25
# 2  random text             random text             2006-03-25
# 3  random text             random text             2011-04-26
# 4  random text             random text             2011-09-05
#
#   Current Due Date  Original QTY UOI  Current QTY UOI  Original Net Price UOI  \
# 0       2018-05-25                 0                0            9.589672e+06
# 1       2004-12-02                 0                0            7.607661e+06
# 2       2015-03-05                 0                0            6.599571e+06
# 3       2018-06-29                 0                0            3.894846e+06
# 4       2006-10-03                 0                0            4.710326e+06
#
#          ...         Purchase Officer Name  Requested By ID  \
# 0        ...                   random text            75755
# 1        ...                   random text            80962
# 2        ...                   random text            70930
# 3        ...                   random text            79836
# 4        ...                   random text            79813
#
#    Requested By Name Authorised By ID Authorised By Name Request by Pos  \
# 0        random text            78281        random text           2623
# 1        random text            71353        random text           2852
# 2        random text            69185        random text           4102
# 3        random text            77719        random text           1127
# 4        random text            68325        random text           3429
#
#   New  Requested  New Requested By  Unnamed: 35  Waiver Indicator
# 0   48551.912050       random text            0       random text
# 1   15177.755150       random text            0       random text
# 2   46637.450473       random text            0       random text
# 3   72819.367288       random text            0       random text
# 4   51426.545825       random text            0       random text
#
# [5 rows x 37 columns]
#    District Code Purchase Order Number  Purchase Order Item Number  \
# 0    random text           random text                           1
# 1    random text           random text                           1
# 2    random text           random text                           1
# 3    random text           random text                           1
# 4    random text           random text                           1
# 5    random text           random text                           1
# 6    random text           random text                           1
# 7    random text           random text                           1
# 8    random text           random text                           1
# 9    random text           random text                           1
# 10   random text           random text                           1
# 11   random text           random text                           1
# 12   random text           random text                           1
# 13   random text           random text                           1
# 14   random text           random text                           1
# 15   random text           random text                           1
# 16   random text           random text                           1
# 17   random text           random text                           1
# 18   random text           random text                           1
# 19   random text           random text                           1
# 20   random text           random text                           1
# 21   random text           random text                           1
# 22   random text           random text                           1
# 23   random text           random text                           1
# 24   random text           random text                           1
# 25   random text           random text                           1
# 26   random text           random text                           1
# 27   random text           random text                           1
# 28   random text           random text                           1
# 29   random text           random text                           1
# ..           ...                   ...                         ...
# 70   random text           random text                           1
# 71   random text           random text                           1
# 72   random text           random text                           1
# 73   random text           random text                           1
# 74   random text           random text                           1
# 75   random text           random text                           1
# 76   random text           random text                           1
# 77   random text           random text                           1
# 78   random text           random text                           1
# 79   random text           random text                           1
# 80   random text           random text                           1
# 81   random text           random text                           1
# 82   random text           random text                           1
# 83   random text           random text                           1
# 84   random text           random text                           1
# 85   random text           random text                           1
# 86   random text           random text                           1
# 87   random text           random text                           1
# 88   random text           random text                           1
# 89   random text           random text                           1
# 90   random text           random text                           1
# 91   random text           random text                           1
# 92   random text           random text                           1
# 93   random text           random text                           1
# 94   random text           random text                           1
# 95   random text           random text                           1
# 96   random text           random text                           1
# 97   random text           random text                           1
# 98   random text           random text                           1
# 99   random text           random text                           1
#
#    Warehouse ID Item Description Detail Date of Purchase Order  \
# 0   random text             random text             2004-06-08
# 1   random text             random text             2014-09-09
# 2   random text             random text             2006-04-09
# 3   random text             random text             2011-05-11
# 4   random text             random text             2011-09-20
# 5   random text             random text             2004-03-09
# 6   random text             random text             2015-05-12
# 7   random text             random text             2011-06-14
# 8   random text             random text             2013-04-09
# 9   random text             random text             2007-01-31
# 10  random text             random text             2015-12-26
# 11  random text             random text             2011-11-26
# 12  random text             random text             2010-09-06
# 13  random text             random text             2004-06-25
# 14  random text             random text             2013-07-18
# 15  random text             random text             2005-05-01
# 16  random text             random text             2010-12-27
# 17  random text             random text             2012-02-21
# 18  random text             random text             2005-11-08
# 19  random text             random text             2007-12-22
# 20  random text             random text             2013-07-06
# 21  random text             random text             2008-12-17
# 22  random text             random text             2006-10-31
# 23  random text             random text             2006-08-13
# 24  random text             random text             2015-11-18
# 25  random text             random text             2011-09-02
# 26  random text             random text             2013-08-31
# 27  random text             random text             2007-06-15
# 28  random text             random text             2010-10-21
# 29  random text             random text             2015-11-15
# ..          ...                     ...                    ...
# 70  random text             random text             2004-06-16
# 71  random text             random text             2007-07-20
# 72  random text             random text             2007-02-12
# 73  random text             random text             2007-06-23
# 74  random text             random text             2008-11-28
# 75  random text             random text             2008-09-15
# 76  random text             random text             2011-11-08
# 77  random text             random text             2005-01-20
# 78  random text             random text             2008-09-18
# 79  random text             random text             2016-04-16
# 80  random text             random text             2007-11-03
# 81  random text             random text             2014-11-27
# 82  random text             random text             2005-10-01
# 83  random text             random text             2011-05-08
# 84  random text             random text             2006-09-18
# 85  random text             random text             2008-02-05
# 86  random text             random text             2008-09-19
# 87  random text             random text             2014-06-06
# 88  random text             random text             2014-04-06
# 89  random text             random text             2004-01-21
# 90  random text             random text             2004-07-12
# 91  random text             random text             2012-03-25
# 92  random text             random text             2009-01-25
# 93  random text             random text             2006-03-24
# 94  random text             random text             2004-03-17
# 95  random text             random text             2008-07-20
# 96  random text             random text             2010-07-16
# 97  random text             random text             2012-08-02
# 98  random text             random text             2005-06-14
# 99  random text             random text             2005-02-17
#
#    Current Due Date  Original QTY UOI  Current QTY UOI  \
# 0        2018-06-09                 0                0
# 1        2004-12-17                 0                0
# 2        2015-03-20                 0                0
# 3        2018-07-14                 0                0
# 4        2006-10-18                 0                0
# 5        2011-11-19                 0                0
# 6        2012-03-30                 0                0
# 7        2018-02-28                 0                0
# 8        2004-09-17                 0                0
# 9        2015-11-20                 0                0
# 10       2011-12-23                 0                0
# 11       2013-10-18                 0                0
# 12       2007-08-11                 0                0
# 13       2016-07-05                 0                0
# 14       2012-06-05                 0                0
# 15       2011-03-17                 0                0
# 16       2005-01-03                 0                0
# 17       2014-01-26                 0                0
# 18       2017-05-12                 0                0
# 19       2005-11-09                 0                0
# 20       2011-07-07                 0                0
# 21       2012-08-31                 0                0
# 22       2006-05-19                 0                0
# 23       2008-07-01                 0                0
# 24       2014-01-14                 0                0
# 25       2009-06-27                 0                0
# 26       2007-05-11                 0                0
# 27       2007-02-21                 0                0
# 28       2016-05-28                 0                0
# 29       2012-03-12                 0                0
# ..              ...               ...              ...
# 70       2013-03-08                 0                0
# 71       2006-02-03                 0                0
# 72       2007-11-29                 0                0
# 73       2014-11-10                 0                0
# 74       2008-11-30                 0                0
# 75       2011-12-25                 0                0
# 76       2015-05-18                 0                0
# 77       2004-12-25                 0                0
# 78       2008-01-28                 0                0
# 79       2007-08-23                 0                0
# 80       2018-01-27                 0                0
# 81       2018-10-01                 0                0
# 82       2017-06-08                 0                0
# 83       2008-01-01                 0                0
# 84       2009-06-08                 0                0
# 85       2009-03-26                 0                0
# 86       2012-05-18                 0                0
# 87       2005-07-31                 0                0
# 88       2009-03-29                 0                0
# 89       2017-01-28                 0                0
# 90       2016-10-25                 0                0
# 91       2008-05-13                 0                0
# 92       2015-06-07                 0                0
# 93       2006-04-11                 0                0
# 94       2011-11-16                 0                0
# 95       2018-07-17                 0                0
# 96       2007-03-29                 0                0
# 97       2016-12-27                 0                0
# 98       2008-08-15                 0                0
# 99       2017-12-01                 0                0
#
#     Original Net Price UOI        ...         Purchase Officer Name  \
# 0             2.464022e+06        ...                   random text
# 1             2.877976e+06        ...                   random text
# 2             2.580931e+06        ...                   random text
# 3             3.913049e+06        ...                   random text
# 4             8.556549e+06        ...                   random text
# 5             9.778820e+06        ...                   random text
# 6             8.823835e+06        ...                   random text
# 7             8.651677e+06        ...                   random text
# 8             5.251593e+06        ...                   random text
# 9             4.529582e+06        ...                   random text
# 10            9.828056e+06        ...                   random text
# 11            2.484615e+06        ...                   random text
# 12            8.969497e+06        ...                   random text
# 13            2.405606e+06        ...                   random text
# 14            4.404458e+06        ...                   random text
# 15            9.505938e+06        ...                   random text
# 16            2.891364e+06        ...                   random text
# 17            6.015659e+06        ...                   random text
# 18            9.500442e+06        ...                   random text
# 19            4.544151e+06        ...                   random text
# 20            4.792071e+06        ...                   random text
# 21            3.108181e+06        ...                   random text
# 22            3.833273e+06        ...                   random text
# 23            2.067175e+06        ...                   random text
# 24            6.748293e+06        ...                   random text
# 25            3.557281e+06        ...                   random text
# 26            6.674784e+06        ...                   random text
# 27            3.222853e+06        ...                   random text
# 28            9.111816e+06        ...                   random text
# 29            7.407419e+06        ...                   random text
# ..                     ...        ...                           ...
# 70            4.314916e+06        ...                   random text
# 71            9.600241e+06        ...                   random text
# 72            4.167019e+06        ...                   random text
# 73            2.714118e+06        ...                   random text
# 74            8.642778e+06        ...                   random text
# 75            2.959002e+06        ...                   random text
# 76            5.247830e+06        ...                   random text
# 77            5.225463e+06        ...                   random text
# 78            4.526998e+06        ...                   random text
# 79            9.778889e+06        ...                   random text
# 80            6.094516e+06        ...                   random text
# 81            6.504774e+06        ...                   random text
# 82            4.441027e+06        ...                   random text
# 83            8.611048e+06        ...                   random text
# 84            4.079562e+06        ...                   random text
# 85            7.131870e+06        ...                   random text
# 86            9.186400e+06        ...                   random text
# 87            3.542745e+06        ...                   random text
# 88            6.674041e+06        ...                   random text
# 89            3.752920e+06        ...                   random text
# 90            7.296982e+06        ...                   random text
# 91            3.152024e+06        ...                   random text
# 92            8.807588e+06        ...                   random text
# 93            5.216029e+06        ...                   random text
# 94            4.369007e+06        ...                   random text
# 95            9.043661e+06        ...                   random text
# 96            7.382139e+06        ...                   random text
# 97            9.797126e+06        ...                   random text
# 98            8.081770e+06        ...                   random text
# 99            3.348389e+06        ...                   random text
#
#     Requested By ID  Requested By Name Authorised By ID Authorised By Name  \
# 0             81634        random text            75783        random text
# 1             70970        random text            76234        random text
# 2             81065        random text            80703        random text
# 3             78196        random text            80970        random text
# 4             68346        random text            70331        random text
# 5             70829        random text            72275        random text
# 6             72826        random text            79745        random text
# 7             68952        random text            80452        random text
# 8             79875        random text            68675        random text
# 9             69415        random text            75246        random text
# 10            78480        random text            67565        random text
# 11            76442        random text            75758        random text
# 12            71977        random text            70585        random text
# 13            76765        random text            81775        random text
# 14            72005        random text            80590        random text
# 15            80464        random text            69200        random text
# 16            78984        random text            68121        random text
# 17            71804        random text            69733        random text
# 18            76979        random text            70477        random text
# 19            70813        random text            79391        random text
# 20            81823        random text            73413        random text
# 21            80368        random text            67427        random text
# 22            70555        random text            71286        random text
# 23            67636        random text            74513        random text
# 24            75079        random text            76757        random text
# 25            81775        random text            75490        random text
# 26            81306        random text            73976        random text
# 27            68814        random text            75927        random text
# 28            71004        random text            70288        random text
# 29            70534        random text            74545        random text
# ..              ...                ...              ...                ...
# 70            71662        random text            70742        random text
# 71            72331        random text            77501        random text
# 72            73907        random text            83407        random text
# 73            77749        random text            79710        random text
# 74            80196        random text            67535        random text
# 75            78858        random text            82542        random text
# 76            65546        random text            68279        random text
# 77            75820        random text            75204        random text
# 78            78272        random text            81300        random text
# 79            65427        random text            70805        random text
# 80            65757        random text            69677        random text
# 81            77092        random text            82405        random text
# 82            73955        random text            67931        random text
# 83            81866        random text            72130        random text
# 84            79835        random text            73809        random text
# 85            78332        random text            73341        random text
# 86            65494        random text            71137        random text
# 87            74390        random text            68802        random text
# 88            71019        random text            81712        random text
# 89            73125        random text            73516        random text
# 90            76091        random text            77252        random text
# 91            69604        random text            76449        random text
# 92            75373        random text            80063        random text
# 93            72372        random text            81025        random text
# 94            65334        random text            76204        random text
# 95            78758        random text            69105        random text
# 96            68477        random text            73097        random text
# 97            67166        random text            81345        random text
# 98            81450        random text            80004        random text
# 99            78968        random text            79107        random text
#
#    Request by Pos New  Requested  New Requested By  Unnamed: 35  \
# 0            3507   73923.872505       random text            0
# 1            2482   30948.193164       random text            0
# 2            3527   40005.688740       random text            0
# 3            3761   74979.433259       random text            0
# 4            4278   61520.712173       random text            0
# 5            4111   18486.981080       random text            0
# 6            1684   68870.888357       random text            0
# 7            4162   38660.942500       random text            0
# 8            3120   64379.871846       random text            0
# 9            1995   19126.452666       random text            0
# 10           1207   63355.409265       random text            0
# 11           1696   40782.367334       random text            0
# 12           2602   43728.755494       random text            0
# 13           1126   58894.973509       random text            0
# 14           3675   54741.056362       random text            0
# 15           4314   16887.798574       random text            0
# 16           1183   49856.626712       random text            0
# 17           1462   71562.776809       random text            0
# 18           3125   22687.702717       random text            0
# 19           2052   64386.229874       random text            0
# 20           2020   46639.540957       random text            0
# 21           1678   21607.222308       random text            0
# 22           4422   51224.496292       random text            0
# 23           3267   24516.119232       random text            0
# 24           1360   24327.682342       random text            0
# 25           3196   42498.934950       random text            0
# 26           1957   55188.793657       random text            0
# 27           1897   30061.943153       random text            0
# 28           4242   31263.486025       random text            0
# 29           2612   25415.894569       random text            0
# ..            ...            ...               ...          ...
# 70           3720   28490.782922       random text            0
# 71           1740   47006.121834       random text            0
# 72           1376   75724.504242       random text            0
# 73           3787   57680.394243       random text            0
# 74           3684   50180.743718       random text            0
# 75           1017   68572.654600       random text            0
# 76           3673   40055.348233       random text            0
# 77           2748   67751.222721       random text            0
# 78           4432   69739.894027       random text            0
# 79           1569   17715.224618       random text            0
# 80           3091   54842.876647       random text            0
# 81           4029   52804.024198       random text            0
# 82           3377   69096.642848       random text            0
# 83           2435   28213.648210       random text            0
# 84           3377   75450.054808       random text            0
# 85           1342   59627.508864       random text            0
# 86           3881   65205.891253       random text            0
# 87           1993   49884.878496       random text            0
# 88           2667   32932.469264       random text            0
# 89           3029   53378.535483       random text            0
# 90           4223   68798.745720       random text            0
# 91           2907   73698.372745       random text            0
# 92           1417   73525.850091       random text            0
# 93           1833   52461.832866       random text            0
# 94           1689   47288.388926       random text            0
# 95           3760   37285.359143       random text            0
# 96           1542   19130.313389       random text            0
# 97           3993   62542.737160       random text            0
# 98           3705   41267.180799       random text            0
# 99           3526   73739.339291       random text            0
#
#     Waiver Indicator
# 0        random text
# 1        random text
# 2        random text
# 3        random text
# 4        random text
# 5        random text
# 6        random text
# 7        random text
# 8        random text
# 9        random text
# 10       random text
# 11       random text
# 12       random text
# 13       random text
# 14       random text
# 15       random text
# 16       random text
# 17       random text
# 18       random text
# 19       random text
# 20       random text
# 21       random text
# 22       random text
# 23       random text
# 24       random text
# 25       random text
# 26       random text
# 27       random text
# 28       random text
# 29       random text
# ..               ...
# 70       random text
# 71       random text
# 72       random text
# 73       random text
# 74       random text
# 75       random text
# 76       random text
# 77       random text
# 78       random text
# 79       random text
# 80       random text
# 81       random text
# 82       random text
# 83       random text
# 84       random text
# 85       random text
# 86       random text
# 87       random text
# 88       random text
# 89       random text
# 90       random text
# 91       random text
# 92       random text
# 93       random text
# 94       random text
# 95       random text
# 96       random text
# 97       random text
# 98       random text
# 99       random text
#
# [100 rows x 37 columns]

# %%
# !jupyter nbconvert \
    --TagRemovePreprocessor.enabled=True \
    --TagRemovePreprocessor.remove_cell_tags="['build', 'test']" \
    --TemplateExporter.exclude_output=True \
    --to python "obfuscate_files.ipynb"

first_line = """'Obfuscate files package'

__version__ = '0.1'

"""
script_file = Path.cwd() / 'obfuscate_files.py'
script = script_file.read_text()
script_file.write_text(first_line + script)
username = script_file.parent.parent.name
system_name = script_file.parent.name
standardised_script_name = f'pipomatic_{username}_{system_name}.py'
script_file.replace(script_file.parent / standardised_script_name)
standardised_script_name
# Out:
# [NbConvertApp] Converting notebook obfuscate_files.ipynb to python
# [NbConvertApp] Writing 3680 bytes to obfuscate_files.py
# 'pipomatic_pipomatic_obfuscate_files.py'

# %%
# !black "pipomatic_pipomatic_obfuscate_files.py"
# Out:
# reformatted pipomatic_pipomatic_obfuscate_files.py
# All done! \u2728 \U0001f370 \u2728
# 1 file reformatted.
