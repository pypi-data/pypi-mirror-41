# %% [markdown]
# To do:
#
# Replace each unique value with the same random text

# %%
from pathlib import Path
import numpy as np
import pandas as pd
from pandas.api.types import is_datetime64_any_dtype, is_numeric_dtype, is_integer_dtype, is_object_dtype, is_string_dtype

# %%
def delete_files(folder):
    file_generator = folder.glob('**/*')
    file_list = list(file_generator)
    for file in file_list:
        file.unlink()
    return list(file_list)


def move_files(samples_folder, file_to_copy, destination_folder):
    (destination_folder / file_to_copy).write_bytes((samples_folder / file_to_copy).read_bytes())
    return file_to_copy


def convert_to_numeric_and_date(df, dayfirst=True):
    for column in df.columns:
        if is_object_dtype(df[column]) or is_string_dtype(df[column]):
            try:
                df[column] = pd.to_numeric(df[column], downcast='integer')
            except:
                try:
                    df[column] = df[column].str.replace('$', '')
                    df[column] = df[column].str.replace(',', '')
                    df[column] = pd.to_numeric(df[column])
                except:
                    try:
                        df[column] = pd.to_datetime(df[column], dayfirst=dayfirst)
                    except:
                        pass
    return df


def random_dates(start, end, seed=1, replace=True, number_of_rows=100):
    dates = pd.date_range(start, end).to_series()
    return dates.sample(number_of_rows, replace=replace, random_state=seed).index
    
    
def dataframe_obfuscator(df, number_of_rows=100):
    for column in df.columns:
        if is_datetime64_any_dtype(df[column]):
            df[column] = random_dates(min(df[column]),max(df[column]), seed=1)
        elif is_integer_dtype(df[column]):
            df[column] = df[column].fillna(0)
            if min(df[column]) < max(df[column]):
                df[column] = np.random.randint(min(df[column]),max(df[column]),size=(number_of_rows))
            else:
                df[column] = min(df[column])
        elif is_numeric_dtype(df[column]):
            df[column] = df[column].fillna(0)
            df[column] = np.random.uniform(min(df[column]),max(df[column]),size=(number_of_rows))
        else:
            df[column] = 'random text'
    return df


def obfuscate_csv(data_file, dayfirst=True, number_of_rows=100):
    df = pd.read_csv(data_file, nrows=number_of_rows)
    df = convert_to_numeric_and_date(df)
    df = dataframe_obfuscator(df)
    df.to_csv(data_file, header=True, index=False)
    return df


def obfuscate_excel(data_file, dayfirst=True, number_of_rows=100):
    df = pd.read_excel(data_file, nrows=number_of_rows)
    display(df.head())
    df = convert_to_numeric_and_date(df)
    df = dataframe_obfuscator(df)
    df.to_excel(data_file, header=True, index=False)
    return df

# %%
p = Path.cwd()
obfuscate_csv(p / 'data' / 'data.csv', dayfirst=True, number_of_rows=100)
# Out:
#    Purchase_Order_Number_Combined District_Code Warehouse_Identification  \
# 0                     random text   random text              random text
# 1                     random text   random text              random text
# 2                     random text   random text              random text
# 3                     random text   random text              random text
# 4                     random text   random text              random text
# 5                     random text   random text              random text
# 6                     random text   random text              random text
# 7                     random text   random text              random text
# 8                     random text   random text              random text
# 9                     random text   random text              random text
# 10                    random text   random text              random text
# 11                    random text   random text              random text
# 12                    random text   random text              random text
# 13                    random text   random text              random text
# 14                    random text   random text              random text
# 15                    random text   random text              random text
# 16                    random text   random text              random text
# 17                    random text   random text              random text
# 18                    random text   random text              random text
# 19                    random text   random text              random text
# 20                    random text   random text              random text
# 21                    random text   random text              random text
# 22                    random text   random text              random text
# 23                    random text   random text              random text
# 24                    random text   random text              random text
# 25                    random text   random text              random text
# 26                    random text   random text              random text
# 27                    random text   random text              random text
# 28                    random text   random text              random text
# 29                    random text   random text              random text
# ..                            ...           ...                      ...
# 70                    random text   random text              random text
# 71                    random text   random text              random text
# 72                    random text   random text              random text
# 73                    random text   random text              random text
# 74                    random text   random text              random text
# 75                    random text   random text              random text
# 76                    random text   random text              random text
# 77                    random text   random text              random text
# 78                    random text   random text              random text
# 79                    random text   random text              random text
# 80                    random text   random text              random text
# 81                    random text   random text              random text
# 82                    random text   random text              random text
# 83                    random text   random text              random text
# 84                    random text   random text              random text
# 85                    random text   random text              random text
# 86                    random text   random text              random text
# 87                    random text   random text              random text
# 88                    random text   random text              random text
# 89                    random text   random text              random text
# 90                    random text   random text              random text
# 91                    random text   random text              random text
# 92                    random text   random text              random text
# 93                    random text   random text              random text
# 94                    random text   random text              random text
# 95                    random text   random text              random text
# 96                    random text   random text              random text
# 97                    random text   random text              random text
# 98                    random text   random text              random text
# 99                    random text   random text              random text
#
#       FPA_Group  FPA_Agreement_Number  FPA_Item_Number Supplier_Price_Code1  \
# 0   random text              0.760261              223          random text
# 1   random text              0.582487              185          random text
# 2   random text              0.752160              178          random text
# 3   random text              0.850549              207          random text
# 4   random text              0.633861              270          random text
# 5   random text              0.385189              249          random text
# 6   random text              0.680826               70          random text
# 7   random text              0.638170              147          random text
# 8   random text              0.390517              215          random text
# 9   random text              0.197937              154          random text
# 10  random text              0.270854              261          random text
# 11  random text              0.557529              218          random text
# 12  random text              0.206382               64          random text
# 13  random text              0.786683              251          random text
# 14  random text              0.173001              109          random text
# 15  random text              0.537350               66          random text
# 16  random text              0.719070              239          random text
# 17  random text              0.811270              133          random text
# 18  random text              0.302937              239          random text
# 19  random text              0.559616               62          random text
# 20  random text              0.313765              100          random text
# 21  random text              0.325118              168          random text
# 22  random text              0.494350              221          random text
# 23  random text              0.537981              172          random text
# 24  random text              0.636399               51          random text
# 25  random text              0.152085              227          random text
# 26  random text              0.236161               94          random text
# 27  random text              0.734612              241          random text
# 28  random text              0.180610              132          random text
# 29  random text              0.188877              267          random text
# ..          ...                   ...              ...                  ...
# 70  random text              0.584817              112          random text
# 71  random text              0.306471              120          random text
# 72  random text              0.650966              170          random text
# 73  random text              0.667359              162          random text
# 74  random text              0.611047              250          random text
# 75  random text              0.722464              225          random text
# 76  random text              0.209850              212          random text
# 77  random text              0.836066              227          random text
# 78  random text              0.515110              130          random text
# 79  random text              0.368900              220          random text
# 80  random text              0.502956              126          random text
# 81  random text              0.694141               71          random text
# 82  random text              0.510014              172          random text
# 83  random text              0.831286              268          random text
# 84  random text              0.237223               96          random text
# 85  random text              0.492085               91          random text
# 86  random text              0.487783              151          random text
# 87  random text              0.228550              264          random text
# 88  random text              0.261497              142          random text
# 89  random text              0.570021              224          random text
# 90  random text              0.493368              233          random text
# 91  random text              0.718270              245          random text
# 92  random text              0.449915              124          random text
# 93  random text              0.311664              179          random text
# 94  random text              0.583084              216          random text
# 95  random text              0.266472              265          random text
# 96  random text              0.368360              121          random text
# 97  random text              0.664011              214          random text
# 98  random text              0.352858               78          random text
# 99  random text              0.710012              121          random text
#
#     UOI_Original_Quantity  UOI_Original_Net_Price1  UOI_Current_Quantity1  \
# 0              195.306035             8.105034e+06             469.318913
# 1              126.586278             1.615573e+06             108.948563
# 2              132.587661             8.010683e+06             290.354216
# 3              271.795281             5.851519e+06             468.748702
# 4              367.691936             4.942879e+06             477.666990
# 5              262.157876             7.962414e+06             111.340883
# 6               66.007860             6.480366e+06             582.132068
# 7              326.415090             5.513623e+06             370.715114
# 8              182.133827             5.998815e+06             124.146810
# 9              215.427062             3.734918e+06             129.887420
# 10             151.172710             5.917218e+06             598.151186
# 11             248.906001             7.325523e+06             291.735472
# 12             409.662102             7.020125e+06             443.639386
# 13             394.674882             2.300381e+06             120.901625
# 14             134.087689             5.301647e+06             241.337141
# 15             381.914761             7.001401e+06             151.346603
# 16             156.442214             6.577104e+06             142.705448
# 17             226.692070             2.781654e+06             104.457490
# 18             229.952909             6.061022e+06             573.566933
# 19             139.617092             5.962437e+06             155.831698
# 20             254.602826             4.046276e+06             448.961091
# 21             155.500232             4.676325e+06              98.207681
# 22             154.125705             1.987564e+06             486.596641
# 23             101.680250             5.290715e+06             290.105231
# 24             428.395908             1.813420e+06             122.214056
# 25             146.237056             4.008321e+06             351.583726
# 26              97.635913             1.569130e+06             265.668379
# 27             183.204938             1.878933e+06             320.270265
# 28             116.899672             4.656780e+06             278.797016
# 29              81.963243             6.984566e+06             353.971212
# ..                    ...                      ...                    ...
# 70             412.124920             1.351309e+06             208.272314
# 71             290.911523             2.644678e+06             574.177009
# 72             136.532431             2.272629e+06             285.789646
# 73             416.488530             6.561894e+06             172.867126
# 74             156.191450             5.547530e+06             339.114381
# 75             142.279054             5.095067e+06             436.120946
# 76             425.967981             7.368559e+06             525.447510
# 77             386.720086             4.883747e+06             579.677231
# 78             393.202940             6.651212e+06             380.534610
# 79             360.345336             6.141962e+06             423.634978
# 80             190.556345             2.242991e+06             458.442061
# 81             280.654701             1.374253e+06             388.915231
# 82              91.695390             3.562638e+06             227.603602
# 83             124.383564             5.715416e+06             140.443646
# 84             171.569003             2.680512e+06             313.614555
# 85              92.348591             2.257473e+06             514.318678
# 86             160.815548             4.903577e+06             386.480063
# 87              68.197177             4.380987e+06             296.818989
# 88              98.154631             5.979267e+06             589.186896
# 89             215.308702             3.616833e+06             482.467086
# 90             182.780660             2.416164e+06             238.272158
# 91             102.043387             3.819305e+06             205.314294
# 92             374.483260             7.908338e+06             530.246779
# 93              85.836051             2.796553e+06             159.265505
# 94             318.910919             6.946061e+06             593.912838
# 95             152.368618             2.277186e+06             131.594691
# 96             355.513622             2.580860e+06             146.457799
# 97              83.244362             1.500902e+06             250.705613
# 98             189.390861             3.616622e+06             186.672585
# 99             137.456152             1.553216e+06             373.733785
#
#          ...               Total    Stock_Code  Item_Name_line  \
# 0        ...         2827.686067  2.998104e+06     random text
# 1        ...         2681.319577  1.196800e+06     random text
# 2        ...         1520.571316  8.889347e+05     random text
# 3        ...         5416.027099  2.515904e+06     random text
# 4        ...         3881.468722  6.772164e+05     random text
# 5        ...         2859.741059  1.278107e+06     random text
# 6        ...         1122.176666  2.283849e+06     random text
# 7        ...         2338.463333  2.984335e+06     random text
# 8        ...         1123.258915  6.654679e+05     random text
# 9        ...         2931.612681  2.307193e+06     random text
# 10       ...         5572.516227  1.334036e+06     random text
# 11       ...         3235.623231  1.328356e+06     random text
# 12       ...         5201.535350  1.954075e+06     random text
# 13       ...         2682.845675  1.167065e+06     random text
# 14       ...         3622.177805  1.649002e+06     random text
# 15       ...         4551.534549  9.593018e+05     random text
# 16       ...         1547.019596  1.699323e+06     random text
# 17       ...         1854.692187  1.874335e+06     random text
# 18       ...         3925.243211  1.574017e+06     random text
# 19       ...         1296.070347  2.297381e+06     random text
# 20       ...         1807.999554  1.987522e+06     random text
# 21       ...         2829.030247  3.024730e+06     random text
# 22       ...         4122.382524  1.668768e+06     random text
# 23       ...         2896.743664  2.205890e+06     random text
# 24       ...         1020.666066  2.517940e+06     random text
# 25       ...         3576.229088  2.815853e+06     random text
# 26       ...         2980.870273  1.389704e+06     random text
# 27       ...         4444.546943  2.633805e+06     random text
# 28       ...         1202.678420  1.731388e+06     random text
# 29       ...         1402.431567  3.003253e+06     random text
# ..       ...                 ...           ...             ...
# 70       ...         3124.576953  2.209744e+06     random text
# 71       ...         2322.793988  2.154679e+06     random text
# 72       ...         5396.568512  2.900431e+06     random text
# 73       ...         3612.233509  5.378971e+05     random text
# 74       ...         5021.225423  2.005127e+06     random text
# 75       ...         3634.630347  1.386760e+06     random text
# 76       ...         2269.758770  1.509048e+06     random text
# 77       ...         3687.772753  2.154247e+06     random text
# 78       ...         5067.866166  2.071096e+06     random text
# 79       ...         1466.649889  5.166652e+05     random text
# 80       ...         4163.814483  8.203466e+05     random text
# 81       ...         2057.289520  2.890724e+06     random text
# 82       ...         2550.313790  2.548064e+06     random text
# 83       ...         2859.768199  1.323059e+06     random text
# 84       ...         2164.481239  6.994059e+05     random text
# 85       ...         1606.266299  1.771359e+06     random text
# 86       ...         1410.739468  1.853600e+06     random text
# 87       ...         1358.149520  6.888131e+05     random text
# 88       ...         1015.483355  4.823129e+05     random text
# 89       ...         1027.884261  7.145416e+05     random text
# 90       ...         1823.029483  3.060872e+06     random text
# 91       ...         4940.909683  2.729129e+06     random text
# 92       ...         1930.099669  8.699238e+05     random text
# 93       ...         2451.098862  2.310312e+06     random text
# 94       ...         2017.403191  9.135355e+05     random text
# 95       ...         2467.068331  1.080813e+06     random text
# 96       ...         3400.250806  1.376587e+06     random text
# 97       ...         2756.121383  1.886971e+06     random text
# 98       ...         2171.103255  9.624360e+05     random text
# 99       ...         5512.816138  2.195505e+06     random text
#
#    Stock_Description Employee_Identification     FullName Purchase_Order_Date  \
# 0        random text             random text  random text          2001-07-04
# 1        random text             random text  random text          2011-10-05
# 2        random text             random text  random text          2003-05-05
# 3        random text             random text  random text          2008-06-05
# 4        random text             random text  random text          2008-10-15
# 5        random text             random text  random text          2001-04-04
# 6        random text             random text  random text          2012-06-06
# 7        random text             random text  random text          2008-07-09
# 8        random text             random text  random text          2010-05-05
# 9        random text             random text  random text          2004-02-26
# 10       random text             random text  random text          2013-01-20
# 11       random text             random text  random text          2008-12-21
# 12       random text             random text  random text          2007-10-02
# 13       random text             random text  random text          2001-07-21
# 14       random text             random text  random text          2010-08-13
# 15       random text             random text  random text          2013-11-27
# 16       random text             random text  random text          2002-05-27
# 17       random text             random text  random text          2008-01-22
# 18       random text             random text  random text          2009-03-18
# 19       random text             random text  random text          2002-12-04
# 20       random text             random text  random text          2005-01-16
# 21       random text             random text  random text          2010-08-01
# 22       random text             random text  random text          2006-01-12
# 23       random text             random text  random text          2003-11-26
# 24       random text             random text  random text          2003-09-08
# 25       random text             random text  random text          2012-12-13
# 26       random text             random text  random text          2008-09-27
# 27       random text             random text  random text          2010-09-26
# 28       random text             random text  random text          2004-07-10
# 29       random text             random text  random text          2007-11-16
# ..               ...                     ...          ...                 ...
# 70       random text             random text  random text          2005-06-17
# 71       random text             random text  random text          2008-07-11
# 72       random text             random text  random text          2011-12-03
# 73       random text             random text  random text          2001-07-12
# 74       random text             random text  random text          2004-08-14
# 75       random text             random text  random text          2004-03-09
# 76       random text             random text  random text          2013-12-24
# 77       random text             random text  random text          2004-07-18
# 78       random text             random text  random text          2005-12-24
# 79       random text             random text  random text          2005-10-11
# 80       random text             random text  random text          2008-12-03
# 81       random text             random text  random text          2002-02-15
# 82       random text             random text  random text          2005-10-14
# 83       random text             random text  random text          2013-08-15
# 84       random text             random text  random text          2013-05-12
# 85       random text             random text  random text          2004-11-28
# 86       random text             random text  random text          2011-12-23
# 87       random text             random text  random text          2002-10-27
# 88       random text             random text  random text          2008-06-02
# 89       random text             random text  random text          2003-10-14
# 90       random text             random text  random text          2013-07-14
# 91       random text             random text  random text          2005-03-02
# 92       random text             random text  random text          2005-10-15
# 93       random text             random text  random text          2011-07-02
# 94       random text             random text  random text          2011-05-02
# 95       random text             random text  random text          2001-02-15
# 96       random text             random text  random text          2001-08-07
# 97       random text             random text  random text          2009-04-20
# 98       random text             random text  random text          2006-02-20
# 99       random text             random text  random text          2003-04-19
#
#    Supplier_Number Supplier_Name Item_Status_Code
# 0      random text   random text                1
# 1      random text   random text                1
# 2      random text   random text                1
# 3      random text   random text                1
# 4      random text   random text                1
# 5      random text   random text                1
# 6      random text   random text                1
# 7      random text   random text                1
# 8      random text   random text                1
# 9      random text   random text                1
# 10     random text   random text                1
# 11     random text   random text                1
# 12     random text   random text                1
# 13     random text   random text                1
# 14     random text   random text                1
# 15     random text   random text                1
# 16     random text   random text                1
# 17     random text   random text                1
# 18     random text   random text                1
# 19     random text   random text                1
# 20     random text   random text                1
# 21     random text   random text                1
# 22     random text   random text                1
# 23     random text   random text                1
# 24     random text   random text                1
# 25     random text   random text                1
# 26     random text   random text                1
# 27     random text   random text                1
# 28     random text   random text                1
# 29     random text   random text                1
# ..             ...           ...              ...
# 70     random text   random text                1
# 71     random text   random text                1
# 72     random text   random text                1
# 73     random text   random text                1
# 74     random text   random text                1
# 75     random text   random text                1
# 76     random text   random text                1
# 77     random text   random text                1
# 78     random text   random text                1
# 79     random text   random text                1
# 80     random text   random text                1
# 81     random text   random text                1
# 82     random text   random text                1
# 83     random text   random text                1
# 84     random text   random text                1
# 85     random text   random text                1
# 86     random text   random text                1
# 87     random text   random text                1
# 88     random text   random text                1
# 89     random text   random text                1
# 90     random text   random text                1
# 91     random text   random text                1
# 92     random text   random text                1
# 93     random text   random text                1
# 94     random text   random text                1
# 95     random text   random text                1
# 96     random text   random text                1
# 97     random text   random text                1
# 98     random text   random text                1
# 99     random text   random text                1
#
# [100 rows x 21 columns]

# %%
p = Path.cwd()
obfuscate_excel(p / 'data' / 'data.xls', dayfirst=True, number_of_rows=100)
# Out:
#   District Code Purchase Order Number  Purchase Order Item Number  \
# 0   random text           random text                           1
# 1   random text           random text                           1
# 2   random text           random text                           1
# 3   random text           random text                           1
# 4   random text           random text                           1
#
#   Warehouse ID Item Description Detail Date of Purchase Order  \
# 0  random text             random text             2004-05-09
# 1  random text             random text             2014-08-10
# 2  random text             random text             2006-03-10
# 3  random text             random text             2011-04-11
# 4  random text             random text             2011-08-21
#
#   Current Due Date  Original QTY UOI  Current QTY UOI  Original Net Price UOI  \
# 0       2018-05-10                 0                0            5.047648e+06
# 1       2004-11-17                 0                0            4.211645e+06
# 2       2015-02-18                 0                0            3.223764e+06
# 3       2018-06-14                 0                0            9.841358e+06
# 4       2006-09-18                 0                0            3.833806e+06
#
#          ...         Purchase Officer Name  Requested By ID  \
# 0        ...                   random text            76715
# 1        ...                   random text            76596
# 2        ...                   random text            75553
# 3        ...                   random text            72812
# 4        ...                   random text            80510
#
#    Requested By Name Authorised By ID Authorised By Name Request by Pos  \
# 0        random text            78571        random text           3847
# 1        random text            73742        random text           1635
# 2        random text            77054        random text           3942
# 3        random text            74330        random text           3119
# 4        random text            68144        random text           2862
#
#   New  Requested  New Requested By  Unnamed: 35  Waiver Indicator
# 0   25078.706632       random text            0       random text
# 1   64936.433000       random text            0       random text
# 2   23246.371111       random text            0       random text
# 3   54548.341954       random text            0       random text
# 4   62174.798694       random text            0       random text
#
# [5 rows x 37 columns]
#    District Code Purchase Order Number  Purchase Order Item Number  \
# 0    random text           random text                           1
# 1    random text           random text                           1
# 2    random text           random text                           1
# 3    random text           random text                           1
# 4    random text           random text                           1
# 5    random text           random text                           1
# 6    random text           random text                           1
# 7    random text           random text                           1
# 8    random text           random text                           1
# 9    random text           random text                           1
# 10   random text           random text                           1
# 11   random text           random text                           1
# 12   random text           random text                           1
# 13   random text           random text                           1
# 14   random text           random text                           1
# 15   random text           random text                           1
# 16   random text           random text                           1
# 17   random text           random text                           1
# 18   random text           random text                           1
# 19   random text           random text                           1
# 20   random text           random text                           1
# 21   random text           random text                           1
# 22   random text           random text                           1
# 23   random text           random text                           1
# 24   random text           random text                           1
# 25   random text           random text                           1
# 26   random text           random text                           1
# 27   random text           random text                           1
# 28   random text           random text                           1
# 29   random text           random text                           1
# ..           ...                   ...                         ...
# 70   random text           random text                           1
# 71   random text           random text                           1
# 72   random text           random text                           1
# 73   random text           random text                           1
# 74   random text           random text                           1
# 75   random text           random text                           1
# 76   random text           random text                           1
# 77   random text           random text                           1
# 78   random text           random text                           1
# 79   random text           random text                           1
# 80   random text           random text                           1
# 81   random text           random text                           1
# 82   random text           random text                           1
# 83   random text           random text                           1
# 84   random text           random text                           1
# 85   random text           random text                           1
# 86   random text           random text                           1
# 87   random text           random text                           1
# 88   random text           random text                           1
# 89   random text           random text                           1
# 90   random text           random text                           1
# 91   random text           random text                           1
# 92   random text           random text                           1
# 93   random text           random text                           1
# 94   random text           random text                           1
# 95   random text           random text                           1
# 96   random text           random text                           1
# 97   random text           random text                           1
# 98   random text           random text                           1
# 99   random text           random text                           1
#
#    Warehouse ID Item Description Detail Date of Purchase Order  \
# 0   random text             random text             2004-05-24
# 1   random text             random text             2014-08-25
# 2   random text             random text             2006-03-25
# 3   random text             random text             2011-04-26
# 4   random text             random text             2011-09-05
# 5   random text             random text             2004-02-23
# 6   random text             random text             2015-04-27
# 7   random text             random text             2011-05-30
# 8   random text             random text             2013-03-25
# 9   random text             random text             2007-01-16
# 10  random text             random text             2015-12-11
# 11  random text             random text             2011-11-11
# 12  random text             random text             2010-08-22
# 13  random text             random text             2004-06-10
# 14  random text             random text             2013-07-03
# 15  random text             random text             2005-04-16
# 16  random text             random text             2010-12-12
# 17  random text             random text             2012-02-06
# 18  random text             random text             2005-10-24
# 19  random text             random text             2007-12-07
# 20  random text             random text             2013-06-21
# 21  random text             random text             2008-12-02
# 22  random text             random text             2006-10-16
# 23  random text             random text             2006-07-29
# 24  random text             random text             2015-11-03
# 25  random text             random text             2011-08-18
# 26  random text             random text             2013-08-16
# 27  random text             random text             2007-05-31
# 28  random text             random text             2010-10-06
# 29  random text             random text             2015-10-31
# ..          ...                     ...                    ...
# 70  random text             random text             2014-10-23
# 71  random text             random text             2004-06-01
# 72  random text             random text             2007-07-05
# 73  random text             random text             2007-01-28
# 74  random text             random text             2007-06-08
# 75  random text             random text             2008-11-13
# 76  random text             random text             2008-08-31
# 77  random text             random text             2011-10-24
# 78  random text             random text             2005-01-05
# 79  random text             random text             2008-09-03
# 80  random text             random text             2016-04-01
# 81  random text             random text             2007-10-19
# 82  random text             random text             2014-11-12
# 83  random text             random text             2005-09-16
# 84  random text             random text             2011-04-23
# 85  random text             random text             2006-09-03
# 86  random text             random text             2008-01-21
# 87  random text             random text             2008-09-04
# 88  random text             random text             2014-05-22
# 89  random text             random text             2014-03-22
# 90  random text             random text             2004-01-06
# 91  random text             random text             2004-06-27
# 92  random text             random text             2012-03-10
# 93  random text             random text             2009-01-10
# 94  random text             random text             2006-03-09
# 95  random text             random text             2004-03-02
# 96  random text             random text             2008-07-05
# 97  random text             random text             2010-07-01
# 98  random text             random text             2012-07-18
# 99  random text             random text             2005-05-30
#
#    Current Due Date  Original QTY UOI  Current QTY UOI  \
# 0        2018-05-25                 0                0
# 1        2004-12-02                 0                0
# 2        2015-03-05                 0                0
# 3        2018-06-29                 0                0
# 4        2006-10-03                 0                0
# 5        2011-11-04                 0                0
# 6        2012-03-15                 0                0
# 7        2018-02-13                 0                0
# 8        2004-09-02                 0                0
# 9        2015-11-05                 0                0
# 10       2011-12-08                 0                0
# 11       2013-10-03                 0                0
# 12       2007-07-27                 0                0
# 13       2018-12-28                 0                0
# 14       2016-06-20                 0                0
# 15       2012-05-21                 0                0
# 16       2011-03-02                 0                0
# 17       2004-12-19                 0                0
# 18       2014-01-11                 0                0
# 19       2017-04-27                 0                0
# 20       2005-10-25                 0                0
# 21       2011-06-22                 0                0
# 22       2012-08-16                 0                0
# 23       2006-05-04                 0                0
# 24       2008-06-16                 0                0
# 25       2013-12-30                 0                0
# 26       2009-06-12                 0                0
# 27       2007-04-26                 0                0
# 28       2007-02-06                 0                0
# 29       2016-05-13                 0                0
# ..              ...               ...              ...
# 70       2011-07-07                 0                0
# 71       2013-02-21                 0                0
# 72       2006-01-19                 0                0
# 73       2007-11-14                 0                0
# 74       2014-10-26                 0                0
# 75       2008-11-15                 0                0
# 76       2011-12-10                 0                0
# 77       2015-05-03                 0                0
# 78       2004-12-10                 0                0
# 79       2008-01-13                 0                0
# 80       2007-08-08                 0                0
# 81       2018-01-12                 0                0
# 82       2018-09-16                 0                0
# 83       2017-05-24                 0                0
# 84       2007-12-17                 0                0
# 85       2009-05-24                 0                0
# 86       2009-03-11                 0                0
# 87       2012-05-03                 0                0
# 88       2018-12-27                 0                0
# 89       2005-07-16                 0                0
# 90       2009-03-14                 0                0
# 91       2017-01-13                 0                0
# 92       2016-10-10                 0                0
# 93       2008-04-28                 0                0
# 94       2015-05-23                 0                0
# 95       2006-03-27                 0                0
# 96       2011-11-01                 0                0
# 97       2018-07-02                 0                0
# 98       2007-03-14                 0                0
# 99       2016-12-12                 0                0
#
#     Original Net Price UOI        ...         Purchase Officer Name  \
# 0             9.589672e+06        ...                   random text
# 1             7.607661e+06        ...                   random text
# 2             6.599571e+06        ...                   random text
# 3             3.894846e+06        ...                   random text
# 4             4.710326e+06        ...                   random text
# 5             4.952511e+06        ...                   random text
# 6             8.226127e+06        ...                   random text
# 7             8.625302e+06        ...                   random text
# 8             3.858707e+06        ...                   random text
# 9             7.107095e+06        ...                   random text
# 10            4.676468e+06        ...                   random text
# 11            5.831338e+06        ...                   random text
# 12            4.066530e+06        ...                   random text
# 13            4.324710e+06        ...                   random text
# 14            5.986172e+06        ...                   random text
# 15            7.412468e+06        ...                   random text
# 16            3.701798e+06        ...                   random text
# 17            7.047001e+06        ...                   random text
# 18            9.288118e+06        ...                   random text
# 19            8.450345e+06        ...                   random text
# 20            9.004879e+06        ...                   random text
# 21            6.359498e+06        ...                   random text
# 22            7.786181e+06        ...                   random text
# 23            6.812730e+06        ...                   random text
# 24            5.558952e+06        ...                   random text
# 25            8.348366e+06        ...                   random text
# 26            3.564862e+06        ...                   random text
# 27            8.783707e+06        ...                   random text
# 28            3.704416e+06        ...                   random text
# 29            6.592773e+06        ...                   random text
# ..                     ...        ...                           ...
# 70            5.691163e+06        ...                   random text
# 71            4.812126e+06        ...                   random text
# 72            4.562838e+06        ...                   random text
# 73            8.570586e+06        ...                   random text
# 74            9.838889e+06        ...                   random text
# 75            2.938918e+06        ...                   random text
# 76            4.857785e+06        ...                   random text
# 77            9.886076e+06        ...                   random text
# 78            6.745239e+06        ...                   random text
# 79            9.274754e+06        ...                   random text
# 80            9.026597e+06        ...                   random text
# 81            5.998531e+06        ...                   random text
# 82            3.287470e+06        ...                   random text
# 83            7.841751e+06        ...                   random text
# 84            6.965400e+06        ...                   random text
# 85            8.351977e+06        ...                   random text
# 86            5.904223e+06        ...                   random text
# 87            4.696066e+06        ...                   random text
# 88            5.637200e+06        ...                   random text
# 89            4.996790e+06        ...                   random text
# 90            3.739368e+06        ...                   random text
# 91            4.086415e+06        ...                   random text
# 92            3.193685e+06        ...                   random text
# 93            2.825188e+06        ...                   random text
# 94            2.134193e+06        ...                   random text
# 95            4.228445e+06        ...                   random text
# 96            7.448732e+06        ...                   random text
# 97            7.143463e+06        ...                   random text
# 98            5.395186e+06        ...                   random text
# 99            5.916042e+06        ...                   random text
#
#     Requested By ID  Requested By Name Authorised By ID Authorised By Name  \
# 0             75755        random text            78281        random text
# 1             80962        random text            71353        random text
# 2             70930        random text            69185        random text
# 3             79836        random text            77719        random text
# 4             79813        random text            68325        random text
# 5             67134        random text            77726        random text
# 6             71480        random text            73361        random text
# 7             67245        random text            73480        random text
# 8             73389        random text            82549        random text
# 9             79022        random text            70788        random text
# 10            81688        random text            84510        random text
# 11            78845        random text            77614        random text
# 12            67806        random text            76148        random text
# 13            66378        random text            71171        random text
# 14            68307        random text            68727        random text
# 15            73165        random text            80922        random text
# 16            70718        random text            82740        random text
# 17            68687        random text            73720        random text
# 18            72482        random text            72796        random text
# 19            80605        random text            82778        random text
# 20            75551        random text            71013        random text
# 21            74650        random text            79741        random text
# 22            65153        random text            77450        random text
# 23            77500        random text            80809        random text
# 24            78408        random text            67296        random text
# 25            69315        random text            77357        random text
# 26            72788        random text            77916        random text
# 27            78609        random text            77539        random text
# 28            70075        random text            72711        random text
# 29            72904        random text            79297        random text
# ..              ...                ...              ...                ...
# 70            67036        random text            77930        random text
# 71            67835        random text            73000        random text
# 72            66156        random text            70161        random text
# 73            77739        random text            78398        random text
# 74            72310        random text            67894        random text
# 75            69715        random text            73475        random text
# 76            81113        random text            79314        random text
# 77            71453        random text            77090        random text
# 78            81184        random text            67788        random text
# 79            65803        random text            68601        random text
# 80            69500        random text            70624        random text
# 81            70052        random text            77602        random text
# 82            77556        random text            74066        random text
# 83            66432        random text            84170        random text
# 84            68641        random text            74092        random text
# 85            78751        random text            82449        random text
# 86            68246        random text            68990        random text
# 87            77209        random text            67707        random text
# 88            69256        random text            67489        random text
# 89            74960        random text            77229        random text
# 90            70226        random text            75599        random text
# 91            73389        random text            82775        random text
# 92            70625        random text            76579        random text
# 93            71628        random text            81647        random text
# 94            72623        random text            75413        random text
# 95            79039        random text            77184        random text
# 96            81577        random text            73473        random text
# 97            81119        random text            73303        random text
# 98            76979        random text            73699        random text
# 99            72094        random text            81099        random text
#
#    Request by Pos New  Requested  New Requested By  Unnamed: 35  \
# 0            2623   48551.912050       random text            0
# 1            2852   15177.755150       random text            0
# 2            4102   46637.450473       random text            0
# 3            1127   72819.367288       random text            0
# 4            3429   51426.545825       random text            0
# 5            3649   71801.530191       random text            0
# 6            3925   44605.505546       random text            0
# 7            1559   28073.534635       random text            0
# 8            2208   57650.467604       random text            0
# 9            4072   64710.051563       random text            0
# 10           1139   44933.355284       random text            0
# 11           3792   44063.745592       random text            0
# 12           2016   48549.409450       random text            0
# 13           1477   20784.652696       random text            0
# 14           4009   73314.326192       random text            0
# 15            971   31351.467711       random text            0
# 16           3268   14322.144982       random text            0
# 17           3848   70765.092598       random text            0
# 18           3928   72449.591931       random text            0
# 19           2872   64284.949179       random text            0
# 20           3328   61913.805138       random text            0
# 21           2266   23785.752772       random text            0
# 22           4292   21879.222443       random text            0
# 23           2809   58267.116676       random text            0
# 24           3530   51920.156904       random text            0
# 25           3201   50143.988049       random text            0
# 26           3672   38567.200185       random text            0
# 27           2384   72808.382643       random text            0
# 28           2621   30230.158883       random text            0
# 29            999   44393.046340       random text            0
# ..            ...            ...               ...          ...
# 70           4235   26798.969408       random text            0
# 71           3719   71763.414434       random text            0
# 72           3304   65629.374385       random text            0
# 73           2581   38848.641923       random text            0
# 74           4160   22443.948345       random text            0
# 75           3072   52221.441861       random text            0
# 76           4071   51187.949604       random text            0
# 77           2603   44624.252299       random text            0
# 78           1606   68993.069703       random text            0
# 79           3503   73073.978015       random text            0
# 80           3481   53105.492900       random text            0
# 81           3477   25325.062361       random text            0
# 82           3515   65100.443904       random text            0
# 83           3266   21425.161688       random text            0
# 84           4041   45065.108525       random text            0
# 85           3871   35793.098910       random text            0
# 86           2457   16341.360860       random text            0
# 87           4291   24938.828759       random text            0
# 88           2186   51121.207767       random text            0
# 89           2956   76716.205841       random text            0
# 90           1002   76246.214519       random text            0
# 91           1645   47216.976754       random text            0
# 92           4386   71096.805421       random text            0
# 93           3002   61825.635715       random text            0
# 94           3036   21445.907669       random text            0
# 95           1082   19592.650738       random text            0
# 96           1216   69001.079233       random text            0
# 97           1452   53516.403002       random text            0
# 98           4289   43814.440454       random text            0
# 99           3757   64372.040751       random text            0
#
#     Waiver Indicator
# 0        random text
# 1        random text
# 2        random text
# 3        random text
# 4        random text
# 5        random text
# 6        random text
# 7        random text
# 8        random text
# 9        random text
# 10       random text
# 11       random text
# 12       random text
# 13       random text
# 14       random text
# 15       random text
# 16       random text
# 17       random text
# 18       random text
# 19       random text
# 20       random text
# 21       random text
# 22       random text
# 23       random text
# 24       random text
# 25       random text
# 26       random text
# 27       random text
# 28       random text
# 29       random text
# ..               ...
# 70       random text
# 71       random text
# 72       random text
# 73       random text
# 74       random text
# 75       random text
# 76       random text
# 77       random text
# 78       random text
# 79       random text
# 80       random text
# 81       random text
# 82       random text
# 83       random text
# 84       random text
# 85       random text
# 86       random text
# 87       random text
# 88       random text
# 89       random text
# 90       random text
# 91       random text
# 92       random text
# 93       random text
# 94       random text
# 95       random text
# 96       random text
# 97       random text
# 98       random text
# 99       random text
#
# [100 rows x 37 columns]

# %%
# !jupyter nbconvert \
    --TagRemovePreprocessor.enabled=True \
    --TagRemovePreprocessor.remove_cell_tags="['build', 'test']" \
    --TemplateExporter.exclude_output=True \
    --to python "obfuscate_files.ipynb"

first_line = """'Obfuscate files package'

__version__ = '0.1'

"""
script_file = Path.cwd() / 'obfuscate_files.py'
script = script_file.read_text()
script_file.write_text(first_line + script)
username = script_file.parent.parent.name
system_name = script_file.parent.name
standardised_script_name = f'pipomatic_{username}_{system_name}.py'
script_file.replace(script_file.parent / standardised_script_name)
standardised_script_name
# Out:
# [NbConvertApp] Converting notebook obfuscate_files.ipynb to python
# [NbConvertApp] Writing 3586 bytes to obfuscate_files.py
# 'pipomatic_pipomatic_obfuscate_files.py'

# %%
# !black "pipomatic_pipomatic_obfuscate_files.py"
# Out:
# reformatted pipomatic_pipomatic_obfuscate_files.py
# All done! \u2728 \U0001f370 \u2728
# 1 file reformatted.
